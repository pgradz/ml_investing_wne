# %%
import os
import pandas as pd
import logging
import datetime
import joblib
import mlflow.keras
from tensorflow.keras.models import load_model
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger
from ml_investing_wne.xtb.xAPIConnector import APIClient, APIStreamClient, loginCommand
from ml_investing_wne.data_engineering.prepare_dataset import prepare_processed_dataset
import ml_investing_wne.config as config
from ml_investing_wne.train_test_val_split import train_test_val_split
from ml_investing_wne.helper import confusion_matrix_plot, compute_profitability_classes, check_hours
import importlib

logger = logging.getLogger()
logger.setLevel(logging.INFO)
# Out:
# 2022-09-25 13:25:35.964986: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-09-25 13:25:35.965030: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
pd.options.display.max_columns = None

# %%
symbol = 'US500'
auxiliary_symbols = ['VIX', 'TNOTE']
period = 1440

build_model = getattr(importlib.import_module('ml_investing_wne.cnn.{}'.format(config.model)),
                      'build_model')

# %%
df = pd.read_csv(os.path.join(config.raw_data_path_xtb, symbol + '_' + str(period) + '.csv' ), parse_dates=['datetime'])

# %%
df.head()
# Out:
#              ctm                 ctmString     open    close     high  \
# 0  1136242800000  Jan 3, 2006, 12:00:00 AM  12520.0  12688.0  12702.0
# 1  1136329200000  Jan 4, 2006, 12:00:00 AM  12690.0  12735.0  12754.0
# 2  1136415600000  Jan 5, 2006, 12:00:00 AM  12735.0  12735.0  12769.0
# 3  1136502000000  Jan 6, 2006, 12:00:00 AM  12746.0  12855.0  12861.0
# 4  1136761200000  Jan 9, 2006, 12:00:00 AM  12856.0  12902.0  12908.0
#
#        low  vol            datetime
# 0  12457.0  0.0 2006-01-02 23:00:00
# 1  12677.0  0.0 2006-01-03 23:00:00
# 2  12703.0  0.0 2006-01-04 23:00:00
# 3  12746.0  0.0 2006-01-05 23:00:00
# 4  12848.0  0.0 2006-01-08 23:00:00

# %%
def xtb_preprocess(df, resample=True):
    df = df.set_index('datetime')
    df.drop(columns=['ctm', 'ctmString'], inplace=True)
    df = df[['high', 'low', 'close','vol']]
    if resample:
        df = df.resample(config.freq).agg({
                                                       'high': 'max',
                                                       'low': 'min',
                                                       'close': 'last',
                                                        'vol': 'sum'
                                                       })
    df['high'] = df['high'] - df['close']
    df['low'] = df['low'] - df['close']

    df.dropna(inplace=True)
    return df

# %%
df = xtb_preprocess(df, resample=False)
df['y_pred'] = df['close'].shift(-config.steps_ahead) / df['close']
df['y_pred'] = [1 if y > 1 else 0 for y in df['y_pred']]
df['datetime'] = df.index

# %%
df['y_pred'].mean()
# Out:
# 0.5396648044692738

# %%
df
# Out:
#                        high    low    close        vol  y_pred  \
# datetime
# 2006-01-02 23:00:00    14.0 -231.0  12688.0        0.0       1
# 2006-01-03 23:00:00    19.0  -58.0  12735.0        0.0       0
# 2006-01-04 23:00:00    34.0  -32.0  12735.0        0.0       1
# 2006-01-05 23:00:00     6.0 -109.0  12855.0        0.0       1
# 2006-01-08 23:00:00     6.0  -54.0  12902.0        0.0       0
# ...                     ...    ...      ...        ...     ...
# 2022-09-18 22:00:00    42.0 -767.0  39224.0  6044747.0       0
# 2022-09-19 22:00:00   566.0 -361.0  38791.0  6849877.0       0
# 2022-09-20 22:00:00  1281.0  -44.0  37963.0  7085644.0       0
# 2022-09-21 22:00:00   588.0 -106.0  37736.0  7604778.0       0
# 2022-09-22 22:00:00   756.0 -475.0  37076.0  8106722.0       0
#
#                                datetime
# datetime
# 2006-01-02 23:00:00 2006-01-02 23:00:00
# 2006-01-03 23:00:00 2006-01-03 23:00:00
# 2006-01-04 23:00:00 2006-01-04 23:00:00
# 2006-01-05 23:00:00 2006-01-05 23:00:00
# 2006-01-08 23:00:00 2006-01-08 23:00:00
# ...                                 ...
# 2022-09-18 22:00:00 2022-09-18 22:00:00
# 2022-09-19 22:00:00 2022-09-19 22:00:00
# 2022-09-20 22:00:00 2022-09-20 22:00:00
# 2022-09-21 22:00:00 2022-09-21 22:00:00
# 2022-09-22 22:00:00 2022-09-22 22:00:00
#
# [3580 rows x 6 columns]

# %%
files_dict = {symbol: os.path.join(config.raw_data_path_xtb, symbol + '_' + str(period) + '.csv' ) for symbol in auxiliary_symbols}
for n, d in enumerate(files_dict.items()):
    print(n, d)
    if n == 0:
        df_aux = pd.read_csv(d[1], parse_dates=['datetime'])
        df_aux = xtb_preprocess(df_aux, resample=False)
        df_aux = df_aux.add_prefix(d[0] + '_')
    else:
        df_temp = pd.read_csv(d[1], parse_dates=['datetime'])
        df_temp = xtb_preprocess(df_temp, resample=False)
        df_temp = df_temp.add_prefix(d[0] + '_')
        df_aux = df_aux.merge(df_temp, left_index=True, right_index=True, how='outer')
        
    
    #yield pd.read_csv(file, **kwargs, parse_dates=['datetime'], names=names)
# Out:
# 0 ('VIX', '/home/jupyter/ml_investing_wne/src/ml_investing_wne/data/raw/xtb/VIX_1440.csv')
# 1 ('TNOTE', '/home/jupyter/ml_investing_wne/src/ml_investing_wne/data/raw/xtb/TNOTE_1440.csv')

# %%
df_aux[df_aux.isna().any(axis=1)]
# Out:
#                      VIX_high  VIX_low  VIX_close   VIX_vol  TNOTE_high  \
# datetime
# 2009-10-20 22:00:00      60.0      0.0     2630.0       0.0         NaN
# 2009-10-21 22:00:00       0.0      0.0     2650.0       0.0         NaN
# 2009-10-25 23:00:00       0.0      0.0     2610.0       0.0         NaN
# 2009-10-26 23:00:00      75.0      0.0     2585.0       0.0         NaN
# 2009-11-11 23:00:00     224.0    -51.0     2651.0       0.0         NaN
# ...                       ...      ...        ...       ...         ...
# 2018-03-13 23:00:00      20.0    -80.0     1721.0  615539.0         NaN
# 2018-03-14 23:00:00      86.0    -15.0     1663.0  324926.0         NaN
# 2019-10-26 22:00:00      15.0     -5.0     1525.0     720.0         NaN
# 2020-01-19 23:00:00       NaN      NaN        NaN       NaN         6.0
# 2020-03-07 23:00:00       NaN      NaN        NaN       NaN        16.0
#
#                      TNOTE_low  TNOTE_close  TNOTE_vol
# datetime
# 2009-10-20 22:00:00        NaN          NaN        NaN
# 2009-10-21 22:00:00        NaN          NaN        NaN
# 2009-10-25 23:00:00        NaN          NaN        NaN
# 2009-10-26 23:00:00        NaN          NaN        NaN
# 2009-11-11 23:00:00        NaN          NaN        NaN
# ...                        ...          ...        ...
# 2018-03-13 23:00:00        NaN          NaN        NaN
# 2018-03-14 23:00:00        NaN          NaN        NaN
# 2019-10-26 22:00:00        NaN          NaN        NaN
# 2020-01-19 23:00:00       -2.0      12911.0   251879.0
# 2020-03-07 23:00:00      -36.0      13929.0    65843.0
#
# [856 rows x 8 columns]

# %%
df = prepare_processed_dataset(df=df)
# Out:
# [2022-09-25 13:40:00,012][prepare_processed_dataset:89] exported to /home/jupyter/ml_investing_wne/src/ml_investing_wne/data/processed/US500/US500_processed_1440min.csv

# %%
df
# Out:
#                        high    low    close        vol    y_pred  \
# datetime
# 2006-02-20 23:00:00    89.0  -17.0  12830.0        0.0  1.007560
# 2006-02-21 23:00:00    15.0  -97.0  12927.0        0.0  0.996209
# 2006-02-22 23:00:00    60.0  -27.0  12878.0        0.0  1.001242
# 2006-02-23 23:00:00    27.0  -38.0  12894.0        0.0  1.003645
# 2006-02-26 23:00:00    35.0  -57.0  12941.0        0.0  0.989645
# ...                     ...    ...      ...        ...       ...
# 2022-09-15 22:00:00   164.0 -350.0  38879.0  7437122.0  1.008874
# 2022-09-18 22:00:00    42.0 -767.0  39224.0  6044747.0  0.988961
# 2022-09-19 22:00:00   566.0 -361.0  38791.0  6849877.0  0.978655
# 2022-09-20 22:00:00  1281.0  -44.0  37963.0  7085644.0  0.994020
# 2022-09-21 22:00:00   588.0 -106.0  37736.0  7604778.0  0.982510
#
#                             SMA_3         EMA_3          VAR_3    SMA_5  \
# datetime
# 2006-02-20 23:00:00  12865.333333  12838.376377    1057.333333  12830.2
# 2006-02-21 23:00:00  12876.333333  12882.688189    2366.333333  12864.6
# 2006-02-22 23:00:00  12878.333333  12880.344094    2352.333333  12880.2
# 2006-02-23 23:00:00  12899.666667  12887.172047     624.333333  12880.2
# 2006-02-26 23:00:00  12904.333333  12914.086024    1072.333333  12894.0
# ...                           ...           ...            ...      ...
# 2022-09-15 22:00:00  39175.333333  39161.687832  117616.333333  39613.2
# 2022-09-18 22:00:00  39066.333333  39192.843916   30416.333333  39221.8
# 2022-09-19 22:00:00  38964.666667  38991.921958   52376.333333  39108.2
# 2022-09-20 22:00:00  38659.333333  38477.460979  410532.333333  38790.6
# 2022-09-21 22:00:00  38163.333333  38106.730490  308356.333333  38518.6
#
#                             EMA_5     VAR_5   SMA_10        EMA_10  \
# datetime
# 2006-02-20 23:00:00  12816.730397    3096.2  12729.3  12775.835517
# 2006-02-21 23:00:00  12853.486931    2545.8  12767.2  12803.319968
# 2006-02-22 23:00:00  12861.657954    1243.2  12789.3  12816.898156
# 2006-02-23 23:00:00  12872.438636    1243.2  12814.9  12830.916673
# 2006-02-26 23:00:00  12895.292424    1912.5  12842.0  12850.931823
# ...                           ...       ...      ...           ...
# 2022-09-15 22:00:00  39380.560286  833257.2  39705.2  39680.450273
# 2022-09-18 22:00:00  39328.373524   65134.7  39691.6  39597.459315
# 2022-09-19 22:00:00  39149.249016   90694.7  39662.8  39450.830348
# 2022-09-20 22:00:00  38753.832677  243460.3  39481.0  39180.315740
# 2022-09-21 22:00:00  38414.555118  405708.3  39244.8  38917.712878
#
#                            VAR_10        SMA_13        EMA_13         VAR_13  \
# datetime
# 2006-02-20 23:00:00  1.369979e+04  12714.692308  12765.283374   11270.064103
# 2006-02-21 23:00:00  1.279440e+04  12731.538462  12788.385749   14715.102564
# 2006-02-22 23:00:00  1.226646e+04  12749.846154  12801.187785   15441.307692
# 2006-02-23 23:00:00  1.021277e+04  12768.615385  12814.446673   15960.589744
# 2006-02-26 23:00:00  8.830667e+03  12798.846154  12832.525719   13390.974359
# ...                           ...           ...           ...            ...
# 2022-09-15 22:00:00  5.526288e+05  39659.846154  39823.849059  430273.141024
# 2022-09-18 22:00:00  5.649112e+05  39631.230769  39738.156336  444876.525640
# 2022-09-19 22:00:00  6.124120e+05  39563.153846  39602.848288  498521.141024
# 2022-09-20 22:00:00  8.951716e+05  39463.846154  39368.584247  693246.974358
# 2022-09-21 22:00:00  1.129220e+06  39338.923077  39135.357926  924229.743588
#
#                        SMA_20        EMA_20         VAR_20  MACD_12_26_9  \
# datetime
# 2006-02-20 23:00:00  12733.00  12757.894817    9956.842105      0.000772
# 2006-02-21 23:00:00  12745.90  12774.000072   11546.936842     12.710798
# 2006-02-22 23:00:00  12757.45  12783.904827   11810.155263     18.615110
# 2006-02-23 23:00:00  12765.25  12794.390082   12707.565789     24.305211
# 2006-02-26 23:00:00  12770.45  12808.352931   14033.839474     32.235573
# ...                       ...           ...            ...           ...
# 2022-09-15 22:00:00  40127.70  40077.323793  874411.799998   -420.834707
# 2022-09-18 22:00:00  40015.85  39996.054860  810663.186840   -433.843272
# 2022-09-19 22:00:00  39891.70  39881.287731  790086.957892   -473.632394
# 2022-09-20 22:00:00  39715.05  39698.593661  817560.681577   -565.459970
# 2022-09-21 22:00:00  39504.55  39511.679979  715102.576314   -649.068926
#
#                      MACDh_12_26_9  MACDs_12_26_9     RSI_14     RSI_10  \
# datetime
# 2006-02-20 23:00:00      39.148612     -39.147839  55.855596  57.431194
# 2006-02-21 23:00:00      41.486910     -28.776112  61.190579  64.183618
# 2006-02-22 23:00:00      37.912978     -19.297868  57.415749  58.936349
# 2006-02-23 23:00:00      34.882463     -10.577252  58.319918  60.119265
# 2006-02-26 23:00:00      34.250260      -2.014687  60.943287  63.546693
# ...                            ...            ...        ...        ...
# 2022-09-15 22:00:00    -128.245595    -292.589112  38.827100  36.447879
# 2022-09-18 22:00:00    -113.003327    -320.839944  42.170974  41.151116
# 2022-09-19 22:00:00    -122.233960    -351.398434  39.269618  37.301484
# 2022-09-20 22:00:00    -171.249229    -394.210741  34.396286  31.116623
# 2022-09-21 22:00:00    -203.886548    -445.182378  33.180567  29.620559
#
#                          RSI_6  STOCHk_14_3_3  STOCHd_14_3_3     WILLR_14  \
# datetime
# 2006-02-20 23:00:00  60.284813    4928.914141    4921.464646  4815.530303
# 2006-02-21 23:00:00  70.351860    4933.080808    4929.040404  4852.272727
# 2006-02-22 23:00:00  60.981633    4978.632139    4946.875696  4968.093385
# 2006-02-23 23:00:00  62.916962    5031.561726    4981.091558  4974.319066
# 2006-02-26 23:00:00  68.435716    5078.339818    5029.511228  4992.607004
# ...                        ...            ...            ...          ...
# 2022-09-15 22:00:00  33.120404    1262.962963    1311.732657  1153.635505
# 2022-09-18 22:00:00  41.171921    1259.532053    1263.498059  1164.494806
# 2022-09-19 22:00:00  34.852614    1256.331969    1259.608995  1150.865596
# 2022-09-20 22:00:00  25.774706    1246.721225    1254.195083  1124.803274
# 2022-09-21 22:00:00  23.740405    1231.109013    1244.720736  1117.658168
#
#                         BBL_5_2.0  BBM_5_2.0     BBU_5_2.0  BBB_5_2.0  \
# datetime
# 2006-02-20 23:00:00  12730.661867    12830.2  12929.738133   1.551622
# 2006-02-21 23:00:00  12774.341704    12864.6  12954.858296   1.403204
# 2006-02-22 23:00:00  12817.126709    12880.2  12943.273291   0.979384
# 2006-02-23 23:00:00  12817.126709    12880.2  12943.273291   0.979384
# 2006-02-26 23:00:00  12815.769571    12894.0  12972.230429   1.213439
# ...                           ...        ...           ...        ...
# 2022-09-15 22:00:00  37980.281435    39613.2  41246.118565   8.244315
# 2022-09-18 22:00:00  38765.257516    39221.8  39678.342484   2.328004
# 2022-09-19 22:00:00  38569.476472    39108.2  39646.923528   2.755041
# 2022-09-20 22:00:00  37907.948902    38790.6  39673.251098   4.550850
# 2022-09-21 22:00:00  37379.184992    38518.6  39658.015008   5.916181
#
#                      BBP_5_2.0     roc_1  hour  weekday      hour_sin  \
# datetime
# 2006-02-20 23:00:00   0.498995  0.996737    23        0 -2.449294e-16
# 2006-02-21 23:00:00   0.845675  1.007560    23        1 -2.449294e-16
# 2006-02-22 23:00:00   0.482560  0.996209    23        2 -2.449294e-16
# 2006-02-23 23:00:00   0.609397  1.001242    23        3 -2.449294e-16
# 2006-02-26 23:00:00   0.800395  1.003645    23        6 -2.449294e-16
# ...                        ...       ...   ...      ...           ...
# 2022-09-15 22:00:00   0.275188  0.994450    22        3 -2.697968e-01
# 2022-09-18 22:00:00   0.502409  1.008874    22        6 -2.697968e-01
# 2022-09-19 22:00:00   0.205600  0.988961    22        0 -2.697968e-01
# 2022-09-20 22:00:00   0.031185  0.978655    22        1 -2.697968e-01
# 2022-09-21 22:00:00   0.156578  0.994020    22        2 -2.697968e-01
#
#                      hour_cos   weekday_sin  weekday_cos
# datetime
# 2006-02-20 23:00:00  1.000000  0.000000e+00          1.0
# 2006-02-21 23:00:00  1.000000  8.660254e-01          0.5
# 2006-02-22 23:00:00  1.000000  8.660254e-01         -0.5
# 2006-02-23 23:00:00  1.000000  1.224647e-16         -1.0
# 2006-02-26 23:00:00  1.000000 -2.449294e-16          1.0
# ...                       ...           ...          ...
# 2022-09-15 22:00:00  0.962917  1.224647e-16         -1.0
# 2022-09-18 22:00:00  0.962917 -2.449294e-16          1.0
# 2022-09-19 22:00:00  0.962917  0.000000e+00          1.0
# 2022-09-20 22:00:00  0.962917  8.660254e-01          0.5
# 2022-09-21 22:00:00  0.962917  8.660254e-01         -0.5
#
# [3546 rows x 41 columns]

# %%
df = df.merge(df_aux, left_index=True, right_index=True, how='outer')

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [high, low, close, vol, y_pred, SMA_3, EMA_3, VAR_3, SMA_5, EMA_5, VAR_5, SMA_10, EMA_10, VAR_10, SMA_13, EMA_13, VAR_13, SMA_20, EMA_20, VAR_20, MACD_12_26_9, MACDh_12_26_9, MACDs_12_26_9, RSI_14, RSI_10, RSI_6, STOCHk_14_3_3, STOCHd_14_3_3, WILLR_14, BBL_5_2.0, BBM_5_2.0, BBU_5_2.0, BBB_5_2.0, BBP_5_2.0, roc_1, hour, weekday, hour_sin, hour_cos, weekday_sin, weekday_cos]
# Index: []

# %%
df.loc[(df.isna().any(axis=1)) & (df.index>datetime.datetime(2010,1,1,0,0,0))]
# Out:
#                        high    low    close        vol    y_pred  \
# datetime
# 2010-01-05 23:00:00   127.0 -339.0  11224.0        0.0  1.012830
# 2010-01-06 23:00:00    15.0  -99.0  11368.0        0.0  1.003519
# 2010-01-07 23:00:00     5.0 -101.0  11408.0        0.0  0.947055
# 2010-01-10 23:00:00     NaN    NaN      NaN        NaN       NaN
# 2010-01-11 23:00:00     NaN    NaN      NaN        NaN       NaN
# ...                     ...    ...      ...        ...       ...
# 2020-01-19 23:00:00    54.0  -62.0  33244.0  1074634.0  0.998406
# 2020-03-07 23:00:00  1436.0 -117.0  28400.0  1373229.0  0.973275
# 2020-03-21 23:00:00     NaN    NaN      NaN        NaN       NaN
# 2021-04-01 22:00:00   108.0 -144.0  40269.0   188451.0  1.010703
# 2022-09-22 22:00:00     NaN    NaN      NaN        NaN       NaN
#
#                             SMA_3         EMA_3          VAR_3    SMA_5  \
# datetime
# 2010-01-05 23:00:00  10469.666667  10651.224630  427954.333333  10284.8
# 2010-01-06 23:00:00  10906.333333  11009.612315  460704.333333  10544.2
# 2010-01-07 23:00:00  11333.333333  11208.806158    9365.333333  10837.0
# 2010-01-10 23:00:00           NaN           NaN            NaN      NaN
# 2010-01-11 23:00:00           NaN           NaN            NaN      NaN
# ...                           ...           ...            ...      ...
# 2020-01-19 23:00:00  33194.000000  33177.903832    7351.000000  33067.6
# 2020-03-07 23:00:00  29270.333333  29102.080123  844260.333333  29762.0
# 2020-03-21 23:00:00           NaN           NaN            NaN      NaN
# 2021-04-01 22:00:00  40022.333333  40061.788451  103714.333333  39836.8
# 2022-09-22 22:00:00           NaN           NaN            NaN      NaN
#
#                             EMA_5      VAR_5   SMA_10        EMA_10  \
# datetime
# 2010-01-05 23:00:00  10445.912849   280072.7  10161.0  10216.433779
# 2010-01-06 23:00:00  10753.275232   477865.2  10295.2  10425.809456
# 2010-01-07 23:00:00  10971.516822   467178.0  10430.3  10604.389555
# 2010-01-10 23:00:00           NaN        NaN      NaN           NaN
# 2010-01-11 23:00:00           NaN        NaN      NaN           NaN
# ...                           ...        ...      ...           ...
# 2020-01-19 23:00:00  33090.894781    35432.3  32866.8  32905.260549
# 2020-03-07 23:00:00  29511.350783  1059306.5  30102.7  30249.113606
# 2020-03-21 23:00:00           NaN        NaN      NaN           NaN
# 2021-04-01 22:00:00  39894.262793   118610.7  39502.5  39647.075462
# 2022-09-22 22:00:00           NaN        NaN      NaN           NaN
#
#                             VAR_10        SMA_13        EMA_13        VAR_13  \
# datetime
# 2010-01-05 23:00:00  142572.888889  10085.000000  10126.055741  1.285828e+05
# 2010-01-06 23:00:00  282409.288889  10209.307692  10303.476349  2.397761e+05
# 2010-01-07 23:00:00  393416.455555  10327.769231  10461.265442  3.346045e+05
# 2010-01-10 23:00:00            NaN           NaN           NaN           NaN
# 2010-01-11 23:00:00            NaN           NaN           NaN           NaN
# ...                            ...           ...           ...           ...
# 2020-01-19 23:00:00   74636.622225  32768.230769  32809.300768  9.416003e+04
# 2020-03-07 23:00:00  914536.455558  30794.923077  30596.514528  2.507221e+06
# 2020-03-21 23:00:00            NaN           NaN           NaN           NaN
# 2021-04-01 22:00:00  218788.277781  39383.230769  39554.219365  2.161959e+05
# 2022-09-22 22:00:00            NaN           NaN           NaN           NaN
#
#                        SMA_20        EMA_20        VAR_20  MACD_12_26_9  \
# datetime
# 2010-01-05 23:00:00   9937.00   9959.926278  1.331742e+05    305.508689
# 2010-01-06 23:00:00  10035.20  10094.028537  2.158483e+05    379.687490
# 2010-01-07 23:00:00  10128.30  10219.168676  2.933173e+05    436.668744
# 2010-01-10 23:00:00       NaN           NaN           NaN           NaN
# 2010-01-11 23:00:00       NaN           NaN           NaN           NaN
# ...                       ...           ...           ...           ...
# 2020-01-19 23:00:00  32599.75  32606.778381  1.170506e+05    392.028712
# 2020-03-07 23:00:00  31837.85  31168.449597  3.713023e+06   -980.719053
# 2020-03-21 23:00:00       NaN           NaN           NaN           NaN
# 2021-04-01 22:00:00  39417.30  39395.510124  1.555477e+05    296.989777
# 2022-09-22 22:00:00       NaN           NaN           NaN           NaN
#
#                      MACDh_12_26_9  MACDs_12_26_9     RSI_14     RSI_10  \
# datetime
# 2010-01-05 23:00:00      68.285167     237.223522  84.129642  87.586368
# 2010-01-06 23:00:00     113.971175     265.716315  85.176660  88.580699
# 2010-01-07 23:00:00     136.761943     299.906801  85.463546  88.856199
# 2010-01-10 23:00:00            NaN            NaN        NaN        NaN
# 2010-01-11 23:00:00            NaN            NaN        NaN        NaN
# ...                            ...            ...        ...        ...
# 2020-01-19 23:00:00      32.372741     359.655971  76.860041  79.305775
# 2020-03-07 23:00:00    -352.640850    -628.078203  29.585571  27.864225
# 2020-03-21 23:00:00            NaN            NaN        NaN        NaN
# 2021-04-01 22:00:00      83.669157     213.320619  64.949418  69.036427
# 2022-09-22 22:00:00            NaN            NaN        NaN        NaN
#
#                          RSI_6  STOCHk_14_3_3  STOCHd_14_3_3     WILLR_14  \
# datetime
# 2010-01-05 23:00:00  91.367729    3283.584978    3292.316056  2381.330472
# 2010-01-06 23:00:00  92.255308    2896.894845    3195.635986  2412.231760
# 2010-01-07 23:00:00  92.511951    2504.792561    2895.090794  2420.815451
# 2010-01-10 23:00:00        NaN            NaN            NaN          NaN
# 2010-01-11 23:00:00        NaN            NaN            NaN          NaN
# ...                        ...            ...            ...          ...
# 2020-01-19 23:00:00  83.960417    3391.117764    3379.618541  3296.107784
# 2020-03-07 23:00:00  25.620492     913.840558     933.910023   788.174580
# 2020-03-21 23:00:00        NaN            NaN            NaN          NaN
# 2021-04-01 22:00:00  77.475935    3057.210936    3039.913051  2975.771257
# 2022-09-22 22:00:00        NaN            NaN            NaN          NaN
#
#                         BBL_5_2.0  BBM_5_2.0     BBU_5_2.0  BBB_5_2.0  \
# datetime
# 2010-01-05 23:00:00   9338.104357    10284.8  11231.495643  18.409607
# 2010-01-06 23:00:00   9307.604415    10544.2  11780.795585  23.455465
# 2010-01-07 23:00:00   9614.310505    10837.0  12059.689495  22.565092
# 2010-01-10 23:00:00           NaN        NaN           NaN        NaN
# 2010-01-11 23:00:00           NaN        NaN           NaN        NaN
# ...                           ...        ...           ...        ...
# 2020-01-19 23:00:00  32730.875543    33067.6  33404.324457   2.036582
# 2020-03-07 23:00:00  27920.864264    29762.0  31603.135736  12.372393
# 2020-03-21 23:00:00           NaN        NaN           NaN        NaN
# 2021-04-01 22:00:00  39220.720265    39836.8  40452.879735   3.093018
# 2022-09-22 22:00:00           NaN        NaN           NaN        NaN
#
#                      BBP_5_2.0     roc_1  hour  weekday      hour_sin  \
# datetime
# 2010-01-05 23:00:00   0.996041  1.108324  23.0      1.0 -2.449294e-16
# 2010-01-06 23:00:00   0.833092  1.012830  23.0      2.0 -2.449294e-16
# 2010-01-07 23:00:00   0.733502  1.003519  23.0      3.0 -2.449294e-16
# 2010-01-10 23:00:00        NaN       NaN   NaN      NaN           NaN
# 2010-01-11 23:00:00        NaN       NaN   NaN      NaN           NaN
# ...                        ...       ...   ...      ...           ...
# 2020-01-19 23:00:00   0.761935  1.000030  23.0      6.0 -2.449294e-16
# 2020-03-07 23:00:00   0.130120  0.973269  23.0      5.0 -2.449294e-16
# 2020-03-21 23:00:00        NaN       NaN   NaN      NaN           NaN
# 2021-04-01 22:00:00   0.850766  1.003214  22.0      3.0 -2.697968e-01
# 2022-09-22 22:00:00        NaN       NaN   NaN      NaN           NaN
#
#                      hour_cos   weekday_sin  weekday_cos  VIX_high  VIX_low  \
# datetime
# 2010-01-05 23:00:00  1.000000  8.660254e-01          0.5       NaN      NaN
# 2010-01-06 23:00:00  1.000000  8.660254e-01         -0.5       NaN      NaN
# 2010-01-07 23:00:00  1.000000  1.224647e-16         -1.0       NaN      NaN
# 2010-01-10 23:00:00       NaN           NaN          NaN     330.0    -50.0
# 2010-01-11 23:00:00       NaN           NaN          NaN      65.0    -35.0
# ...                       ...           ...          ...       ...      ...
# 2020-01-19 23:00:00  1.000000 -2.449294e-16          1.0       NaN      NaN
# 2020-03-07 23:00:00  1.000000 -8.660254e-01          0.5       NaN      NaN
# 2020-03-21 23:00:00       NaN           NaN          NaN     282.0   -663.0
# 2021-04-01 22:00:00  0.962917  1.224647e-16         -1.0       NaN      NaN
# 2022-09-22 22:00:00       NaN           NaN          NaN     135.0   -203.0
#
#                      VIX_close   VIX_vol  TNOTE_high  TNOTE_low  TNOTE_close  \
# datetime
# 2010-01-05 23:00:00        NaN       NaN         NaN        NaN          NaN
# 2010-01-06 23:00:00        NaN       NaN         NaN        NaN          NaN
# 2010-01-07 23:00:00        NaN       NaN         NaN        NaN          NaN
# 2010-01-10 23:00:00     1989.0       0.0         NaN        NaN          NaN
# 2010-01-11 23:00:00     2009.0       0.0        89.0      -97.0      11593.0
# ...                        ...       ...         ...        ...          ...
# 2020-01-19 23:00:00        NaN       NaN         6.0       -2.0      12911.0
# 2020-03-07 23:00:00        NaN       NaN        16.0      -36.0      13929.0
# 2020-03-21 23:00:00     6963.0    3339.0        20.0       -9.0      13784.0
# 2021-04-01 22:00:00        NaN       NaN         NaN        NaN          NaN
# 2022-09-22 22:00:00     2972.0  646873.0        17.0      -99.0      11275.0
#
#                      TNOTE_vol
# datetime
# 2010-01-05 23:00:00        NaN
# 2010-01-06 23:00:00        NaN
# 2010-01-07 23:00:00        NaN
# 2010-01-10 23:00:00        NaN
# 2010-01-11 23:00:00        0.0
# ...                        ...
# 2020-01-19 23:00:00   251879.0
# 2020-03-07 23:00:00    65843.0
# 2020-03-21 23:00:00        0.0
# 2021-04-01 22:00:00        NaN
# 2022-09-22 22:00:00  5680572.0
#
# [1291 rows x 49 columns]

# %%
temp = df.loc[(df.index>datetime.datetime(2010,1,1,0,0,0))]
temp.loc[(temp.isna().any(axis=1))]
# Out:
#                        high    low    close        vol    y_pred  \
# datetime
# 2010-01-05 23:00:00   127.0 -339.0  11224.0        0.0  1.012830
# 2010-01-06 23:00:00    15.0  -99.0  11368.0        0.0  1.003519
# 2010-01-07 23:00:00     5.0 -101.0  11408.0        0.0  0.947055
# 2010-01-10 23:00:00     NaN    NaN      NaN        NaN       NaN
# 2010-01-11 23:00:00     NaN    NaN      NaN        NaN       NaN
# ...                     ...    ...      ...        ...       ...
# 2020-01-19 23:00:00    54.0  -62.0  33244.0  1074634.0  0.998406
# 2020-03-07 23:00:00  1436.0 -117.0  28400.0  1373229.0  0.973275
# 2020-03-21 23:00:00     NaN    NaN      NaN        NaN       NaN
# 2021-04-01 22:00:00   108.0 -144.0  40269.0   188451.0  1.010703
# 2022-09-22 22:00:00     NaN    NaN      NaN        NaN       NaN
#
#                             SMA_3         EMA_3          VAR_3    SMA_5  \
# datetime
# 2010-01-05 23:00:00  10469.666667  10651.224630  427954.333333  10284.8
# 2010-01-06 23:00:00  10906.333333  11009.612315  460704.333333  10544.2
# 2010-01-07 23:00:00  11333.333333  11208.806158    9365.333333  10837.0
# 2010-01-10 23:00:00           NaN           NaN            NaN      NaN
# 2010-01-11 23:00:00           NaN           NaN            NaN      NaN
# ...                           ...           ...            ...      ...
# 2020-01-19 23:00:00  33194.000000  33177.903832    7351.000000  33067.6
# 2020-03-07 23:00:00  29270.333333  29102.080123  844260.333333  29762.0
# 2020-03-21 23:00:00           NaN           NaN            NaN      NaN
# 2021-04-01 22:00:00  40022.333333  40061.788451  103714.333333  39836.8
# 2022-09-22 22:00:00           NaN           NaN            NaN      NaN
#
#                             EMA_5      VAR_5   SMA_10        EMA_10  \
# datetime
# 2010-01-05 23:00:00  10445.912849   280072.7  10161.0  10216.433779
# 2010-01-06 23:00:00  10753.275232   477865.2  10295.2  10425.809456
# 2010-01-07 23:00:00  10971.516822   467178.0  10430.3  10604.389555
# 2010-01-10 23:00:00           NaN        NaN      NaN           NaN
# 2010-01-11 23:00:00           NaN        NaN      NaN           NaN
# ...                           ...        ...      ...           ...
# 2020-01-19 23:00:00  33090.894781    35432.3  32866.8  32905.260549
# 2020-03-07 23:00:00  29511.350783  1059306.5  30102.7  30249.113606
# 2020-03-21 23:00:00           NaN        NaN      NaN           NaN
# 2021-04-01 22:00:00  39894.262793   118610.7  39502.5  39647.075462
# 2022-09-22 22:00:00           NaN        NaN      NaN           NaN
#
#                             VAR_10        SMA_13        EMA_13        VAR_13  \
# datetime
# 2010-01-05 23:00:00  142572.888889  10085.000000  10126.055741  1.285828e+05
# 2010-01-06 23:00:00  282409.288889  10209.307692  10303.476349  2.397761e+05
# 2010-01-07 23:00:00  393416.455555  10327.769231  10461.265442  3.346045e+05
# 2010-01-10 23:00:00            NaN           NaN           NaN           NaN
# 2010-01-11 23:00:00            NaN           NaN           NaN           NaN
# ...                            ...           ...           ...           ...
# 2020-01-19 23:00:00   74636.622225  32768.230769  32809.300768  9.416003e+04
# 2020-03-07 23:00:00  914536.455558  30794.923077  30596.514528  2.507221e+06
# 2020-03-21 23:00:00            NaN           NaN           NaN           NaN
# 2021-04-01 22:00:00  218788.277781  39383.230769  39554.219365  2.161959e+05
# 2022-09-22 22:00:00            NaN           NaN           NaN           NaN
#
#                        SMA_20        EMA_20        VAR_20  MACD_12_26_9  \
# datetime
# 2010-01-05 23:00:00   9937.00   9959.926278  1.331742e+05    305.508689
# 2010-01-06 23:00:00  10035.20  10094.028537  2.158483e+05    379.687490
# 2010-01-07 23:00:00  10128.30  10219.168676  2.933173e+05    436.668744
# 2010-01-10 23:00:00       NaN           NaN           NaN           NaN
# 2010-01-11 23:00:00       NaN           NaN           NaN           NaN
# ...                       ...           ...           ...           ...
# 2020-01-19 23:00:00  32599.75  32606.778381  1.170506e+05    392.028712
# 2020-03-07 23:00:00  31837.85  31168.449597  3.713023e+06   -980.719053
# 2020-03-21 23:00:00       NaN           NaN           NaN           NaN
# 2021-04-01 22:00:00  39417.30  39395.510124  1.555477e+05    296.989777
# 2022-09-22 22:00:00       NaN           NaN           NaN           NaN
#
#                      MACDh_12_26_9  MACDs_12_26_9     RSI_14     RSI_10  \
# datetime
# 2010-01-05 23:00:00      68.285167     237.223522  84.129642  87.586368
# 2010-01-06 23:00:00     113.971175     265.716315  85.176660  88.580699
# 2010-01-07 23:00:00     136.761943     299.906801  85.463546  88.856199
# 2010-01-10 23:00:00            NaN            NaN        NaN        NaN
# 2010-01-11 23:00:00            NaN            NaN        NaN        NaN
# ...                            ...            ...        ...        ...
# 2020-01-19 23:00:00      32.372741     359.655971  76.860041  79.305775
# 2020-03-07 23:00:00    -352.640850    -628.078203  29.585571  27.864225
# 2020-03-21 23:00:00            NaN            NaN        NaN        NaN
# 2021-04-01 22:00:00      83.669157     213.320619  64.949418  69.036427
# 2022-09-22 22:00:00            NaN            NaN        NaN        NaN
#
#                          RSI_6  STOCHk_14_3_3  STOCHd_14_3_3     WILLR_14  \
# datetime
# 2010-01-05 23:00:00  91.367729    3283.584978    3292.316056  2381.330472
# 2010-01-06 23:00:00  92.255308    2896.894845    3195.635986  2412.231760
# 2010-01-07 23:00:00  92.511951    2504.792561    2895.090794  2420.815451
# 2010-01-10 23:00:00        NaN            NaN            NaN          NaN
# 2010-01-11 23:00:00        NaN            NaN            NaN          NaN
# ...                        ...            ...            ...          ...
# 2020-01-19 23:00:00  83.960417    3391.117764    3379.618541  3296.107784
# 2020-03-07 23:00:00  25.620492     913.840558     933.910023   788.174580
# 2020-03-21 23:00:00        NaN            NaN            NaN          NaN
# 2021-04-01 22:00:00  77.475935    3057.210936    3039.913051  2975.771257
# 2022-09-22 22:00:00        NaN            NaN            NaN          NaN
#
#                         BBL_5_2.0  BBM_5_2.0     BBU_5_2.0  BBB_5_2.0  \
# datetime
# 2010-01-05 23:00:00   9338.104357    10284.8  11231.495643  18.409607
# 2010-01-06 23:00:00   9307.604415    10544.2  11780.795585  23.455465
# 2010-01-07 23:00:00   9614.310505    10837.0  12059.689495  22.565092
# 2010-01-10 23:00:00           NaN        NaN           NaN        NaN
# 2010-01-11 23:00:00           NaN        NaN           NaN        NaN
# ...                           ...        ...           ...        ...
# 2020-01-19 23:00:00  32730.875543    33067.6  33404.324457   2.036582
# 2020-03-07 23:00:00  27920.864264    29762.0  31603.135736  12.372393
# 2020-03-21 23:00:00           NaN        NaN           NaN        NaN
# 2021-04-01 22:00:00  39220.720265    39836.8  40452.879735   3.093018
# 2022-09-22 22:00:00           NaN        NaN           NaN        NaN
#
#                      BBP_5_2.0     roc_1  hour  weekday      hour_sin  \
# datetime
# 2010-01-05 23:00:00   0.996041  1.108324  23.0      1.0 -2.449294e-16
# 2010-01-06 23:00:00   0.833092  1.012830  23.0      2.0 -2.449294e-16
# 2010-01-07 23:00:00   0.733502  1.003519  23.0      3.0 -2.449294e-16
# 2010-01-10 23:00:00        NaN       NaN   NaN      NaN           NaN
# 2010-01-11 23:00:00        NaN       NaN   NaN      NaN           NaN
# ...                        ...       ...   ...      ...           ...
# 2020-01-19 23:00:00   0.761935  1.000030  23.0      6.0 -2.449294e-16
# 2020-03-07 23:00:00   0.130120  0.973269  23.0      5.0 -2.449294e-16
# 2020-03-21 23:00:00        NaN       NaN   NaN      NaN           NaN
# 2021-04-01 22:00:00   0.850766  1.003214  22.0      3.0 -2.697968e-01
# 2022-09-22 22:00:00        NaN       NaN   NaN      NaN           NaN
#
#                      hour_cos   weekday_sin  weekday_cos  VIX_high  VIX_low  \
# datetime
# 2010-01-05 23:00:00  1.000000  8.660254e-01          0.5       NaN      NaN
# 2010-01-06 23:00:00  1.000000  8.660254e-01         -0.5       NaN      NaN
# 2010-01-07 23:00:00  1.000000  1.224647e-16         -1.0       NaN      NaN
# 2010-01-10 23:00:00       NaN           NaN          NaN     330.0    -50.0
# 2010-01-11 23:00:00       NaN           NaN          NaN      65.0    -35.0
# ...                       ...           ...          ...       ...      ...
# 2020-01-19 23:00:00  1.000000 -2.449294e-16          1.0       NaN      NaN
# 2020-03-07 23:00:00  1.000000 -8.660254e-01          0.5       NaN      NaN
# 2020-03-21 23:00:00       NaN           NaN          NaN     282.0   -663.0
# 2021-04-01 22:00:00  0.962917  1.224647e-16         -1.0       NaN      NaN
# 2022-09-22 22:00:00       NaN           NaN          NaN     135.0   -203.0
#
#                      VIX_close   VIX_vol  TNOTE_high  TNOTE_low  TNOTE_close  \
# datetime
# 2010-01-05 23:00:00        NaN       NaN         NaN        NaN          NaN
# 2010-01-06 23:00:00        NaN       NaN         NaN        NaN          NaN
# 2010-01-07 23:00:00        NaN       NaN         NaN        NaN          NaN
# 2010-01-10 23:00:00     1989.0       0.0         NaN        NaN          NaN
# 2010-01-11 23:00:00     2009.0       0.0        89.0      -97.0      11593.0
# ...                        ...       ...         ...        ...          ...
# 2020-01-19 23:00:00        NaN       NaN         6.0       -2.0      12911.0
# 2020-03-07 23:00:00        NaN       NaN        16.0      -36.0      13929.0
# 2020-03-21 23:00:00     6963.0    3339.0        20.0       -9.0      13784.0
# 2021-04-01 22:00:00        NaN       NaN         NaN        NaN          NaN
# 2022-09-22 22:00:00     2972.0  646873.0        17.0      -99.0      11275.0
#
#                      TNOTE_vol
# datetime
# 2010-01-05 23:00:00        NaN
# 2010-01-06 23:00:00        NaN
# 2010-01-07 23:00:00        NaN
# 2010-01-10 23:00:00        NaN
# 2010-01-11 23:00:00        0.0
# ...                        ...
# 2020-01-19 23:00:00   251879.0
# 2020-03-07 23:00:00    65843.0
# 2020-03-21 23:00:00        0.0
# 2021-04-01 22:00:00        NaN
# 2022-09-22 22:00:00  5680572.0
#
# [1291 rows x 49 columns]

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (3546, 41)

# %%
X, y, X_val, y_val, X_test, y_test, y_cat, y_val_cat, y_test_cat, train = train_test_val_split(df)
# Out:
# [2022-09-25 13:40:18,769][split_sequences:24] first sequence begins: 2006-02-20 23:00:00
# [2022-09-25 13:40:18,770][split_sequences:25] first sequence ends: 2006-04-27 22:00:00
# [2022-09-25 13:40:18,784][split_sequences:30] last sequence begins: 2020-10-25 23:00:00
# [2022-09-25 13:40:18,785][split_sequences:31] last sequence ends: 2020-12-30 23:00:00
# [2022-09-25 13:40:18,804][split_sequences:24] first sequence begins: 2020-11-15 23:00:00
# [2022-09-25 13:40:18,805][split_sequences:25] first sequence ends: 2021-01-21 23:00:00
# [2022-09-25 13:40:18,807][split_sequences:30] last sequence begins: 2021-10-26 22:00:00
# [2022-09-25 13:40:18,808][split_sequences:31] last sequence ends: 2021-12-30 23:00:00
# [2022-09-25 13:40:18,810][split_sequences:24] first sequence begins: 2021-11-14 23:00:00
# [2022-09-25 13:40:18,811][split_sequences:25] first sequence ends: 2022-01-19 23:00:00
# [2022-09-25 13:40:18,812][split_sequences:30] last sequence begins: 2022-07-18 22:00:00
# [2022-09-25 13:40:18,813][split_sequences:31] last sequence ends: 2022-09-21 22:00:00

# %%
config.patience = 20

# %%
mlflow.set_experiment(experiment_name='xtb' + '_' + config.model + '_' +
                                      str(config.nb_classes) + '_' +
                                      config.freq + '_' + str(config.steps_ahead) + '_' +
                                      str(config.seq_len))
early_stop = EarlyStopping(monitor='val_accuracy', patience=config.patience, restore_best_weights=True)
model_path_final = os.path.join(config.package_directory, 'models',
                                '{}_{}_{}_{}_{}.h5'.format(config.model, 'xtb',
                                                           config.currency, config.freq,
                                                           config.steps_ahead))
model_checkpoint = ModelCheckpoint(filepath=model_path_final, monitor='val_accuracy', verbose=1,
                                   save_best_only=True)
csv_logger = CSVLogger(os.path.join(config.package_directory, 'logs', 'keras_log.csv'), append=True,
                       separator=';')
callbacks = [early_stop, model_checkpoint, csv_logger]

# %%
X.shape
# Out:
# (3047, 48, 40)

# %%
model = build_model(input_shape=(config.seq_len, X.shape[2]), head_size=64, num_heads=4, ff_dim=64,
                    num_transformer_blocks=2, mlp_units=[128], mlp_dropout=0.25, dropout=0.25)

# %%
model.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 48, 40)]     0
# __________________________________________________________________________________________________
# position_embedding_layer_7 (Pos (None, 48, 40)       1920        input_8[0][0]
# __________________________________________________________________________________________________
# layer_normalization_28 (LayerNo (None, 48, 40)       80          position_embedding_layer_7[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_14 (MultiH (None, 48, 40)       41768       layer_normalization_28[0][0]
#                                                                  layer_normalization_28[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 48, 40)       0           multi_head_attention_14[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_28 (TFOpLa (None, 48, 40)       0           dropout_35[0][0]
#                                                                  position_embedding_layer_7[0][0]
# __________________________________________________________________________________________________
# layer_normalization_29 (LayerNo (None, 48, 40)       80          tf.__operators__.add_28[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 48, 40)       1640        layer_normalization_29[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 48, 40)       0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_29 (TFOpLa (None, 48, 40)       0           dropout_36[0][0]
#                                                                  tf.__operators__.add_28[0][0]
# __________________________________________________________________________________________________
# layer_normalization_30 (LayerNo (None, 48, 40)       80          tf.__operators__.add_29[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_15 (MultiH (None, 48, 40)       41768       layer_normalization_30[0][0]
#                                                                  layer_normalization_30[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 48, 40)       0           multi_head_attention_15[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_30 (TFOpLa (None, 48, 40)       0           dropout_37[0][0]
#                                                                  tf.__operators__.add_29[0][0]
# __________________________________________________________________________________________________
# layer_normalization_31 (LayerNo (None, 48, 40)       80          tf.__operators__.add_30[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 48, 40)       1640        layer_normalization_31[0][0]
# __________________________________________________________________________________________________
# dropout_38 (Dropout)            (None, 48, 40)       0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_31 (TFOpLa (None, 48, 40)       0           dropout_38[0][0]
#                                                                  tf.__operators__.add_30[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_7 (Glo (None, 48)           0           tf.__operators__.add_31[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 128)          6272        global_average_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# dropout_39 (Dropout)            (None, 128)          0           dense_14[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 2)            258         dropout_39[0][0]
# ==================================================================================================
# Total params: 95,586
# Trainable params: 95,586
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit(X, y_cat, batch_size=64, epochs=config.epochs, verbose=2,
                    validation_data=(X_val, y_val_cat), callbacks=callbacks)
# Out:
# Epoch 1/100
# 48/48 - 6s - loss: 0.7195 - accuracy: 0.5021 - val_loss: 0.6820 - val_accuracy: 0.5806
#
# Epoch 00001: val_accuracy improved from -inf to 0.58065, saving model to /home/jupyter/ml_investing_wne/src/ml_investing_wne/models/transformer_learnable_encoding_xtb_US500_1440min_1.h5
# Epoch 2/100
# 48/48 - 4s - loss: 0.6947 - accuracy: 0.5323 - val_loss: 0.6926 - val_accuracy: 0.5242
#
# Epoch 00002: val_accuracy did not improve from 0.58065
# Epoch 3/100
# 48/48 - 5s - loss: 0.6938 - accuracy: 0.5267 - val_loss: 0.6777 - val_accuracy: 0.5887
#
# Epoch 00003: val_accuracy improved from 0.58065 to 0.58871, saving model to /home/jupyter/ml_investing_wne/src/ml_investing_wne/models/transformer_learnable_encoding_xtb_US500_1440min_1.h5
# Epoch 4/100
# 48/48 - 4s - loss: 0.6937 - accuracy: 0.5310 - val_loss: 0.6760 - val_accuracy: 0.5887
#
# Epoch 00004: val_accuracy did not improve from 0.58871
# Epoch 5/100
# 48/48 - 4s - loss: 0.6939 - accuracy: 0.5290 - val_loss: 0.6836 - val_accuracy: 0.5726
#
# Epoch 00005: val_accuracy did not improve from 0.58871
# Epoch 6/100
# 48/48 - 4s - loss: 0.6939 - accuracy: 0.5330 - val_loss: 0.6847 - val_accuracy: 0.5565
#
# Epoch 00006: val_accuracy did not improve from 0.58871
# Epoch 7/100
# 48/48 - 4s - loss: 0.6877 - accuracy: 0.5422 - val_loss: 0.6924 - val_accuracy: 0.5685
#
# Epoch 00007: val_accuracy did not improve from 0.58871
# Epoch 8/100
# 48/48 - 4s - loss: 0.6857 - accuracy: 0.5464 - val_loss: 0.6805 - val_accuracy: 0.5887
#
# Epoch 00008: val_accuracy did not improve from 0.58871
# Epoch 9/100
# 48/48 - 4s - loss: 0.6843 - accuracy: 0.5553 - val_loss: 0.6794 - val_accuracy: 0.5847
#
# Epoch 00009: val_accuracy did not improve from 0.58871
# Epoch 10/100
# 48/48 - 4s - loss: 0.6817 - accuracy: 0.5606 - val_loss: 0.6861 - val_accuracy: 0.5887
#
# Epoch 00010: val_accuracy did not improve from 0.58871
# Epoch 11/100
# 48/48 - 4s - loss: 0.6836 - accuracy: 0.5504 - val_loss: 0.6920 - val_accuracy: 0.5524
#
# Epoch 00011: val_accuracy did not improve from 0.58871
# Epoch 12/100
# 48/48 - 4s - loss: 0.6812 - accuracy: 0.5530 - val_loss: 0.6751 - val_accuracy: 0.5887
#
# Epoch 00012: val_accuracy did not improve from 0.58871
# Epoch 13/100
# 48/48 - 4s - loss: 0.6789 - accuracy: 0.5523 - val_loss: 0.6788 - val_accuracy: 0.5968
#
# Epoch 00013: val_accuracy improved from 0.58871 to 0.59677, saving model to /home/jupyter/ml_investing_wne/src/ml_investing_wne/models/transformer_learnable_encoding_xtb_US500_1440min_1.h5
# Epoch 14/100
# 48/48 - 4s - loss: 0.6780 - accuracy: 0.5635 - val_loss: 0.6820 - val_accuracy: 0.5847
#
# Epoch 00014: val_accuracy did not improve from 0.59677
# Epoch 15/100
# 48/48 - 4s - loss: 0.6712 - accuracy: 0.5747 - val_loss: 0.7009 - val_accuracy: 0.4960
#
# Epoch 00015: val_accuracy did not improve from 0.59677
# Epoch 16/100
# 48/48 - 4s - loss: 0.6688 - accuracy: 0.5622 - val_loss: 0.6801 - val_accuracy: 0.5968
#
# Epoch 00016: val_accuracy did not improve from 0.59677
# Epoch 17/100
# 48/48 - 4s - loss: 0.6621 - accuracy: 0.5875 - val_loss: 0.6782 - val_accuracy: 0.5927
#
# Epoch 00017: val_accuracy did not improve from 0.59677
# Epoch 18/100
# 48/48 - 4s - loss: 0.6606 - accuracy: 0.6019 - val_loss: 0.6812 - val_accuracy: 0.5645
#
# Epoch 00018: val_accuracy did not improve from 0.59677
# Epoch 19/100
# 48/48 - 5s - loss: 0.6518 - accuracy: 0.6035 - val_loss: 0.6812 - val_accuracy: 0.5968
#
# Epoch 00019: val_accuracy did not improve from 0.59677
# Epoch 20/100
# 48/48 - 4s - loss: 0.6429 - accuracy: 0.6170 - val_loss: 0.6809 - val_accuracy: 0.5766
#
# Epoch 00020: val_accuracy did not improve from 0.59677
# Epoch 21/100
# 48/48 - 4s - loss: 0.6339 - accuracy: 0.6186 - val_loss: 0.6870 - val_accuracy: 0.5403
#
# Epoch 00021: val_accuracy did not improve from 0.59677
# Epoch 22/100
# 48/48 - 4s - loss: 0.6260 - accuracy: 0.6488 - val_loss: 0.6721 - val_accuracy: 0.6129
#
# Epoch 00022: val_accuracy improved from 0.59677 to 0.61290, saving model to /home/jupyter/ml_investing_wne/src/ml_investing_wne/models/transformer_learnable_encoding_xtb_US500_1440min_1.h5
# Epoch 23/100
# 48/48 - 4s - loss: 0.6184 - accuracy: 0.6413 - val_loss: 0.6769 - val_accuracy: 0.5887
#
# Epoch 00023: val_accuracy did not improve from 0.61290
# Epoch 24/100
# 48/48 - 4s - loss: 0.6113 - accuracy: 0.6534 - val_loss: 0.6760 - val_accuracy: 0.5847
#
# Epoch 00024: val_accuracy did not improve from 0.61290
# Epoch 25/100
# 48/48 - 4s - loss: 0.5965 - accuracy: 0.6712 - val_loss: 0.6789 - val_accuracy: 0.5645
#
# Epoch 00025: val_accuracy did not improve from 0.61290
# Epoch 26/100
# 48/48 - 4s - loss: 0.5811 - accuracy: 0.6872 - val_loss: 0.6761 - val_accuracy: 0.5605
#
# Epoch 00026: val_accuracy did not improve from 0.61290
# Epoch 27/100
# 48/48 - 4s - loss: 0.5865 - accuracy: 0.6646 - val_loss: 0.6757 - val_accuracy: 0.5847
#
# Epoch 00027: val_accuracy did not improve from 0.61290
# Epoch 28/100
# 48/48 - 4s - loss: 0.5616 - accuracy: 0.6800 - val_loss: 0.6825 - val_accuracy: 0.5645
#
# Epoch 00028: val_accuracy did not improve from 0.61290
# Epoch 29/100
# 48/48 - 4s - loss: 0.5648 - accuracy: 0.7063 - val_loss: 0.6740 - val_accuracy: 0.6048
#
# Epoch 00029: val_accuracy did not improve from 0.61290
# Epoch 30/100
# 48/48 - 4s - loss: 0.5519 - accuracy: 0.7010 - val_loss: 0.6758 - val_accuracy: 0.5968
#
# Epoch 00030: val_accuracy did not improve from 0.61290
# Epoch 31/100
# 48/48 - 4s - loss: 0.5410 - accuracy: 0.7112 - val_loss: 0.6792 - val_accuracy: 0.5968
#
# Epoch 00031: val_accuracy did not improve from 0.61290
# Epoch 32/100
# 48/48 - 4s - loss: 0.5317 - accuracy: 0.7207 - val_loss: 0.6745 - val_accuracy: 0.6089
#
# Epoch 00032: val_accuracy did not improve from 0.61290
# Epoch 33/100
# 48/48 - 4s - loss: 0.5192 - accuracy: 0.7223 - val_loss: 0.6750 - val_accuracy: 0.5847
#
# Epoch 00033: val_accuracy did not improve from 0.61290
# Epoch 34/100
# 48/48 - 4s - loss: 0.5071 - accuracy: 0.7371 - val_loss: 0.6724 - val_accuracy: 0.6089
#
# Epoch 00034: val_accuracy did not improve from 0.61290
# Epoch 35/100
# 48/48 - 4s - loss: 0.5081 - accuracy: 0.7351 - val_loss: 0.6765 - val_accuracy: 0.5806
#
# Epoch 00035: val_accuracy did not improve from 0.61290
# Epoch 36/100
# 48/48 - 4s - loss: 0.4916 - accuracy: 0.7430 - val_loss: 0.6727 - val_accuracy: 0.5726
#
# Epoch 00036: val_accuracy did not improve from 0.61290
# Epoch 37/100
# 48/48 - 4s - loss: 0.4855 - accuracy: 0.7585 - val_loss: 0.6736 - val_accuracy: 0.6008
#
# Epoch 00037: val_accuracy did not improve from 0.61290
# Epoch 38/100
# 48/48 - 4s - loss: 0.4729 - accuracy: 0.7601 - val_loss: 0.6722 - val_accuracy: 0.5726
#
# Epoch 00038: val_accuracy did not improve from 0.61290
# Epoch 39/100
# 48/48 - 4s - loss: 0.4833 - accuracy: 0.7575 - val_loss: 0.6696 - val_accuracy: 0.5887
#
# Epoch 00039: val_accuracy did not improve from 0.61290
# Epoch 40/100
# 48/48 - 4s - loss: 0.4577 - accuracy: 0.7650 - val_loss: 0.6710 - val_accuracy: 0.5847
#
# Epoch 00040: val_accuracy did not improve from 0.61290
# Epoch 41/100
# 48/48 - 4s - loss: 0.4519 - accuracy: 0.7680 - val_loss: 0.6715 - val_accuracy: 0.5887
#
# Epoch 00041: val_accuracy did not improve from 0.61290
# Epoch 42/100
# 48/48 - 4s - loss: 0.4585 - accuracy: 0.7726 - val_loss: 0.6745 - val_accuracy: 0.5685
#
# Epoch 00042: val_accuracy did not improve from 0.61290

# %%
model.evaluate(X_test, y_test_cat)
# Out:
# 6/6 [==============================] - 0s 17ms/step - loss: 0.7526 - accuracy: 0.4746
# [0.7526242733001709, 0.47457626461982727]

# %%
y_pred = model.predict(X_test)
y_pred_class = y_pred.argmax(axis=-1)

if 'JPY' in config.currency:
    df['cost'] = (config.pips / 100) / df['close']
else:
    df['cost'] = (config.pips / 10000) / df['close']

start_date = joblib.load(os.path.join(config.package_directory, 'models',
                                      'first_sequence_ends_{}_{}_{}.save'.format('test',
                                                                                 config.currency,
                                                                                 config.freq)))
end_date = joblib.load(os.path.join(config.package_directory, 'models',
                                    'last_sequence_ends_{}_{}_{}.save'.format('test',
                                                                              config.currency,
                                                                              config.freq)))
lower_bounds = [0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5]
upper_bounds = [1 - lower for lower in lower_bounds]

for lower_bound, upper_bound in zip(lower_bounds, upper_bounds):
    portfolio_result, hit_ratio, time_active = compute_profitability_classes(df, y_pred, start_date,
                                                                             end_date, lower_bound,
                                                                             upper_bound)
# Out:
# /home/jupyter/ml_investing_wne/src/ml_investing_wne/helper.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   'Europe/Warsaw').dt.tz_localize(None)
# /home/jupyter/ml_investing_wne/src/ml_investing_wne/helper.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prediction['hour_waw'] = prediction['datetime_waw'].dt.time
# /home/jupyter/ml_investing_wne/src/ml_investing_wne/helper.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prediction['prediction'] = y_pred[:, 1]
# /home/jupyter/ml_investing_wne/src/ml_investing_wne/helper.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prediction['trade'] = np.select(conditions, values)
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# [2022-09-25 13:51:33,014][compute_profitability_classes:115] share_of_time_active for bounds 0.1-0.9 is 0.0 and hit ratio is 0
# [2022-09-25 13:51:33,105][compute_profitability_classes:123] Portfolio result:  100
# [2022-09-25 13:51:33,210][compute_profitability_classes:115] share_of_time_active for bounds 0.15-0.85 is 0.0 and hit ratio is 0
# [2022-09-25 13:51:33,301][compute_profitability_classes:123] Portfolio result:  100
# [2022-09-25 13:51:33,400][compute_profitability_classes:115] share_of_time_active for bounds 0.2-0.8 is 0.0 and hit ratio is 0
# [2022-09-25 13:51:33,488][compute_profitability_classes:123] Portfolio result:  100
# [2022-09-25 13:51:33,598][compute_profitability_classes:115] share_of_time_active for bounds 0.25-0.75 is 0.02 and hit ratio is 0.75
# [2022-09-25 13:51:33,709][compute_profitability_classes:123] Portfolio result:  100.6993908804483
# [2022-09-25 13:51:33,814][compute_profitability_classes:115] share_of_time_active for bounds 0.3-0.7 is 0.12 and hit ratio is 0.6363636363636364
# [2022-09-25 13:51:33,919][compute_profitability_classes:123] Portfolio result:  103.11074400933292
# [2022-09-25 13:51:34,047][compute_profitability_classes:115] share_of_time_active for bounds 0.35-0.65 is 0.49 and hit ratio is 0.4883720930232558
# [2022-09-25 13:51:34,146][compute_profitability_classes:123] Portfolio result:  94.76158560834867
# [2022-09-25 13:51:34,250][compute_profitability_classes:115] share_of_time_active for bounds 0.4-0.6 is 0.78 and hit ratio is 0.4855072463768116
# [2022-09-25 13:51:34,355][compute_profitability_classes:123] Portfolio result:  86.65934335751845
# [2022-09-25 13:51:34,459][compute_profitability_classes:115] share_of_time_active for bounds 0.45-0.55 is 0.94 and hit ratio is 0.4727272727272727
# [2022-09-25 13:51:34,563][compute_profitability_classes:123] Portfolio result:  82.24104064525991
# [2022-09-25 13:51:34,665][compute_profitability_classes:115] share_of_time_active for bounds 0.5-0.5 is 1.0 and hit ratio is 0.4772727272727273
# [2022-09-25 13:51:34,759][compute_profitability_classes:123] Portfolio result:  84.68011579112726

# %%
y_pred
# Out:
# array([[0.3425434 , 0.6574567 ],
#        [0.32381877, 0.67618126],
#        [0.31618667, 0.68381333],
#        [0.23020212, 0.7697979 ],
#        [0.3261649 , 0.67383516],
#        [0.38393235, 0.61606765],
#        [0.32500538, 0.67499465],
#        [0.4629349 , 0.537065  ],
#        [0.41527194, 0.58472806],
#        [0.3809217 , 0.6190783 ],
#        [0.3650233 , 0.63497674],
#        [0.37059683, 0.6294031 ],
#        [0.43136576, 0.5686343 ],
#        [0.39708212, 0.60291785],
#        [0.49377564, 0.50622433],
#        [0.35678613, 0.64321387],
#        [0.3447483 , 0.6552517 ],
#        [0.43035328, 0.5696468 ],
#        [0.4010485 , 0.5989515 ],
#        [0.40953344, 0.5904665 ],
#        [0.35486674, 0.64513326],
#        [0.30248764, 0.6975124 ],
#        [0.33466938, 0.6653306 ],
#        [0.3077956 , 0.69220436],
#        [0.32982114, 0.67017883],
#        [0.31683165, 0.68316835],
#        [0.30651727, 0.6934827 ],
#        [0.30401242, 0.69598764],
#        [0.29965428, 0.7003457 ],
#        [0.33384892, 0.66615105],
#        [0.33994195, 0.6600581 ],
#        [0.2972571 , 0.70274293],
#        [0.38331595, 0.6166841 ],
#        [0.3438432 , 0.65615684],
#        [0.36133513, 0.63866484],
#        [0.27794692, 0.7220531 ],
#        [0.2964494 , 0.7035506 ],
#        [0.36979523, 0.6302048 ],
#        [0.35622904, 0.643771  ],
#        [0.46190384, 0.53809613],
#        [0.45239463, 0.5476054 ],
#        [0.32717192, 0.6728281 ],
#        [0.32642424, 0.67357576],
#        [0.33759204, 0.662408  ],
#        [0.3826204 , 0.6173796 ],
#        [0.43269536, 0.56730455],
#        [0.38106963, 0.61893046],
#        [0.43600294, 0.56399703],
#        [0.38597247, 0.6140276 ],
#        [0.41609678, 0.58390325],
#        [0.42407975, 0.5759203 ],
#        [0.40227893, 0.59772104],
#        [0.4604637 , 0.5395363 ],
#        [0.37314358, 0.6268564 ],
#        [0.43929487, 0.5607051 ],
#        [0.42308894, 0.57691103],
#        [0.36952367, 0.63047636],
#        [0.384424  , 0.61557597],
#        [0.35572472, 0.64427525],
#        [0.38370934, 0.6162906 ],
#        [0.31862208, 0.6813779 ],
#        [0.27834576, 0.72165424],
#        [0.3271771 , 0.67282283],
#        [0.30790108, 0.69209886],
#        [0.29770303, 0.7022969 ],
#        [0.30647352, 0.6935265 ],
#        [0.2556081 , 0.74439186],
#        [0.28701818, 0.7129819 ],
#        [0.30560762, 0.6943923 ],
#        [0.30145073, 0.6985492 ],
#        [0.29540056, 0.7045994 ],
#        [0.3142569 , 0.68574315],
#        [0.3056615 , 0.69433856],
#        [0.2598752 , 0.74012476],
#        [0.29571688, 0.70428306],
#        [0.35957652, 0.6404234 ],
#        [0.31000224, 0.6899978 ],
#        [0.38229176, 0.61770827],
#        [0.32903814, 0.67096186],
#        [0.482161  , 0.517839  ],
#        [0.35968944, 0.6403105 ],
#        [0.36809412, 0.63190585],
#        [0.42511177, 0.5748882 ],
#        [0.3785894 , 0.6214106 ],
#        [0.3950972 , 0.6049028 ],
#        [0.3465005 , 0.65349954],
#        [0.41149253, 0.5885075 ],
#        [0.3275443 , 0.6724557 ],
#        [0.33538067, 0.66461927],
#        [0.29958832, 0.7004117 ],
#        [0.30191198, 0.698088  ],
#        [0.30397227, 0.6960277 ],
#        [0.2480769 , 0.75192314],
#        [0.33006164, 0.6699384 ],
#        [0.29989415, 0.70010585],
#        [0.37211883, 0.62788117],
#        [0.36385188, 0.63614815],
#        [0.34060454, 0.6593955 ],
#        [0.39131972, 0.60868025],
#        [0.3479044 , 0.6520956 ],
#        [0.39618298, 0.603817  ],
#        [0.3468804 , 0.6531196 ],
#        [0.33868024, 0.66131973],
#        [0.36375266, 0.63624734],
#        [0.41383958, 0.5861605 ],
#        [0.40570295, 0.5942971 ],
#        [0.41772193, 0.5822781 ],
#        [0.4314262 , 0.5685739 ],
#        [0.43158668, 0.5684133 ],
#        [0.3452399 , 0.65476006],
#        [0.36774322, 0.63225687],
#        [0.3911142 , 0.6088858 ],
#        [0.32928166, 0.67071843],
#        [0.37323678, 0.62676316],
#        [0.32272643, 0.6772736 ],
#        [0.302211  , 0.697789  ],
#        [0.33401713, 0.66598284],
#        [0.34732714, 0.6526729 ],
#        [0.36010677, 0.6398933 ],
#        [0.32961357, 0.6703864 ],
#        [0.34712616, 0.6528739 ],
#        [0.31298226, 0.6870178 ],
#        [0.23671973, 0.7632803 ],
#        [0.32299933, 0.6770007 ],
#        [0.27765813, 0.72234184],
#        [0.3274791 , 0.6725208 ],
#        [0.25826105, 0.7417389 ],
#        [0.25350577, 0.74649423],
#        [0.3153853 , 0.68461466],
#        [0.32585433, 0.67414564],
#        [0.37338158, 0.6266184 ],
#        [0.31546926, 0.68453074],
#        [0.32983765, 0.6701624 ],
#        [0.40075108, 0.59924895],
#        [0.36953926, 0.63046074],
#        [0.46353966, 0.53646034],
#        [0.4211487 , 0.57885134],
#        [0.37763408, 0.62236583],
#        [0.42330384, 0.5766962 ],
#        [0.3467525 , 0.65324754],
#        [0.42699724, 0.5730027 ],
#        [0.47128075, 0.5287192 ],
#        [0.3816781 , 0.61832184],
#        [0.4788974 , 0.52110255],
#        [0.39669186, 0.6033082 ],
#        [0.48844245, 0.5115575 ],
#        [0.42679957, 0.57320046],
#        [0.39420936, 0.6057906 ],
#        [0.48456174, 0.51543826],
#        [0.42305583, 0.5769441 ],
#        [0.39388517, 0.6061148 ],
#        [0.39767554, 0.6023244 ],
#        [0.3197113 , 0.6802887 ],
#        [0.39754397, 0.6024561 ],
#        [0.35690328, 0.6430967 ],
#        [0.38121355, 0.61878645],
#        [0.39172748, 0.6082725 ],
#        [0.3335536 , 0.66644645],
#        [0.43938726, 0.56061274],
#        [0.31238917, 0.6876108 ],
#        [0.37019557, 0.62980443],
#        [0.3587131 , 0.64128685],
#        [0.32539794, 0.6746021 ],
#        [0.38970295, 0.6102971 ],
#        [0.28012618, 0.7198738 ],
#        [0.35729492, 0.64270514],
#        [0.3118314 , 0.6881686 ],
#        [0.25726512, 0.74273485],
#        [0.36612138, 0.63387865],
#        [0.23896281, 0.76103723],
#        [0.34268677, 0.6573132 ],
#        [0.3036882 , 0.69631183],
#        [0.3423374 , 0.65766263],
#        [0.42888445, 0.57111555],
#        [0.34759694, 0.65240306],
#        [0.38576716, 0.6142329 ],
#        [0.30432305, 0.695677  ]], dtype=float32)
